# %% [markdown]
# # Math Model: ปัญหาการเรียนรู้คันจิ (Learning kanji Problem)
# สำหรับบันทึกโครงสร้างตัวโปรแกรมของ Math Model ใน Jupyter Notebook ประกอบไปด้วย
# * โจทย์ปัญหา และ ระเบียบวิธีทางเงื่อนไขที่ใช้ในปัญหานี้
# * โครงส้ราง Math Model ในแบบต่างๆ ที่รองรับกับปัญหานี้
# * โปรแกรมอ้างอิงสำหรับตัว Math Model นี้

# %% [markdown]
# ### โจทย์ปัญหาของ Model
# มหาลัยแห่งหนึ่งได้ทำการวิจัยเกี่ยวกับวิธีการเขียนคันจิ และ หลักการทำความเข้าใจคันจิ จนพบว่านักศึกษาส่วนมากมีแนวโน้มที่จะใช้กลยุทธ์ เขียนคันจิที่พึ่งได้เรียนใหม่ ซ้ำๆ เป็นหลักดังตารางด้านล่าง
# <img src="1.png" alt="cce" border="0">
# - [x] <span style="color:brown">ที่มาข้อมูล :</span> งานวิจัย บุษบา บรรจงมณี คณะมนุษย์ศาสตร์ มหาวิทยาลัยเกษตรศาสตร์ ภายใต้หัวข้อ ญี่ปุ่นศึกษา
# - [ ] <span style="color:brown">ที่มาข้อมูล :</span> การประชุมวิชาการระดับชาติ IAMBEST ครั้งที่ 3
#
# จากตารางดังต่อไปนี้ จะทำให้เราทราบเงื่อนไข หรือ สมมติฐานสำหรับการเรียนรู้ตัวอักษรคันจิดังต่อไปนี้
# * ผู้ศึกษาคันจิล้วนมีความรู้เกี่ยวกับตัวอักษรคันจิเริ่มต้นทั้งหมด หรือ อาจจะไม่มีความรู้เกี่ยวกับตัวอักษรคันจิ (K<sub>0</sub>)
# * ผู้ศึกษาคันจิใช้เวลาไปกับการทบทวนตัวอักษรคันจิ ในแต่ละวันขึ้นอยู่กับเป้าหมายที่ตัวเองตั้งไว้ (t)
# * จากกรณีที่ผู้ศึกษาคันจิต้องพยายามทบทวนการใช้ตัวอักษรคันจิ ทำให้มีแนวโน้มที่ผู้ศึกษาสามารถลืมตัวอักษรคันจิได้โดยขึ้นอยู่กับปริมาณข้อมูลตัวอักษรคันจิที่ได้เรียนไปในแต่ละวัน (K<sub>Forgetting Curve</sub> หรือ K<sub>F.C</sub>)
#
# จากสมมติฐานข้างต้น เพื่อทำให้ Math Model มีความสมจริงตามการใช้งานตัวอักษรคันจิในชีวิตประจำวัน เราจึงกำหนดเงื่อนไขดังต่อไปนี้
# * คันจิที่ใช้ในชีวิตประจำวันจะมีปริมาณสูงสุดอยู่ 2,136 ตัว ระดับประถมศึกษา 1,006 ตัว และ ระดับมัธยมศึกษา 1,130 ตัว
# * ให้รวม 送り仮名 และ 語彙 อยู่ในหมวดหมู่เดียวกับคันจิที่ใช้ในชีวิตประจำวัน
# * เพื่อเป็นไปตามแบบแผนการเรียนตัวคันจิที่ถูกต้อง ผู้ศึกษาคันจิจะต้องมีความรู้ตัวคันจิประเภท คำราก ทั้ง 214 ตัว
#
# ดังนั้น จากข้อมูลที่มี ถ้าทางมหาลัยต้องการทราบว่า ผู้ศึกษาคันจิจะต้องใช้เวลาเท่าไหร่ถึงจะจดจำคันจิที่ใช้ในชีวิตประจำวันได้ทั้งหมด โดยที่อยู่ในกรอบของการเรียน 3 เทอม
# (ให้นับวิชา Kanji Studies เทียบเท่ากับวิชา japanese 1 - 3 ตลอดภาคการศึกษา และ ภาคการศึกษาละ 4 เดือน) <br>
# จงสร้างโมเดลที่สามารถแก้ปัญหาข้างต้นนี้

# %% [markdown]
# # <span style="color:blue">A Simple Mathematical Model Part </span>
# มาลองพิจารณา Model อย่างง่ายสำหรับโจทย์ข้อนี้จะได้ดังต่อไปนี้ <br>
# กำหนดให้ $ K_0 , t , r \in \mathbb{N}_+ $
# $$ K(t) = K_0 + rt $$

# %%
import math 
#พิจารณาโจทย์จะได้ สมการ สำหรับโมเดลอย่างง่ายดังนี้
#ส่วนตัวแปร
K_0 = 100
r = 10 #learning rate
t = 10 #time
limit = 160 
#ส่วนโมเดลแบบง่าย
K_t = K_0 + r*t
print(K_t)

#ส่วนลองหาคำตอบว่าจะใช้เวลากี่วันถึงจะเรียนรู้คันจิได้ครบ 2136 
for times in range(1, limit+1):
    K_t = min(K_0 + r*times, 2136)
    if K_t == 2136:
        print(f'ต้องใช้เวลาเรียน {t} วัน ถึงจะจดจำคันจิได้ทั้งหมด 2136 ตัว')
        print(f'คิดเป็นเดือนก็คือต้องใช้เวลา {t//30} เดือน {math.floor(t - (t//30)*30)} วัน ถึงจะจดจำคันจิได้ทั้งหมด 2136 ตัว')
        break
    elif times == limit and K_t < 2136:
        print(f'แม้ว่าจะใช้เวลาครบ {limit} วันแล้ว ผู้ศึกษาคันจิยังคงจดจำคำจิได้เพียง {K_t} ตัว')
        break
# Out:
# 200
# แม้ว่าจะใช้เวลาครบ 160 วันแล้ว ผู้ศึกษาคันจิยังคงจดจำคำจิได้เพียง 1700 ตัว

# %% [markdown]
# # <span style="color:blue">The Mathematical Model Part : Linear Equation </span>
# จากการพิจารณาโจทย์ ทำให้เราพบสิ่งที่พวกเขาต้องการคือ ต้องการทราบว่าจะใช้เวลากี่วันถึงจะเรียนรู้คันจิทั้ง 2,136 ตัวได้ โดยเราตั้งประเด็นหลักไปที่ตัวคันจิดั่งสมการต่อไปนี้ <br>
# กำหนดให้ $ K_0 , t \in \mathbb{N}_+ $ และ $ \alpha , \beta \in \mathbb{R}_+ $
# $$
# \begin{aligned}
# Kl(t) & = K_0 + 𝛼t \\
# r(t) & =  \beta t  \\
# K(t) & = \left\lfloor Kl(t) - r(t) \right\rfloor \\
# K(t) & = \left\lfloor K_0 + 𝛼t - \beta t \right\rfloor
# \end{aligned}
# $$
# โดยตัวแปรแต่ละตัวมีความหมายดังนี้ <br>
# Kl(t) =  Kanji Learned : คันจิที่ผู้ศึกษาคันจิเรียนและจำได้อยู่ (ตัว หรือ 字)<br>
# r(t) = Reduce by losing some kanji : คันจิที่ผู้ศึกษาจะสูญเสียไปหลังศึกษาคันจิในปริมาณมากของวันๆ นั้น (ตัว หรือ 字)<br>
# K(t) = Kanji : คันจิที่ผู้ศึกษาคันจิจำได้ทั้งหมด
# K_0 = Starter Kanji : ตัวอักษรคันจิที่ผู้ศึกษาตัวคันจิรู้ (ตัว หรือ 字)<br>
# (กำหนดให้ K_0  อยู่ที่ 214 ตัว) <br>
# t = Time : เวลา หรือ วันที่ศึกษาคันจิ (วัน) <br>
# $ \alpha $ = $A$ learning kanji rate : ตัวอักษรคันจิที่ผู้ศึกษาคันจิ สามารถศึกษาได้ต่อวัน (ตัว/วัน หรือ 字/วัน) <br>
# $ \beta $ = $B$eing reduce by Forgetting Curve : อัตราการสูญเสียตัวคันจิของผู้ศึกษาคันจิ (ตัว/วัน หรือ 字/วัน)<br>
# (กำหนดให้ $\beta$ จาก Forgetting Curve อยู่ที่ 0.5 หรือ $\frac{5}{10}$)

# %%
import math 
import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np
#ส่วนตัวแปร
K_0 = 100
𝛼 = 10
𝛽 = 𝛼*1/2
#ส่วนฟังก์ชัน
def Al(t):
    all_kanji = K_0 + 𝛼*t
    return(all_kanji)
def r(t):
    reduce_rate = 𝛽*t
    return(reduce_rate)
def K(t):
    now_kanji = math.ceil(Al(t) - r(t))
    return min(now_kanji , 2136)
def LK(t):
    learner_kanji = math.ceil(2136 + 𝛽*t - K_0 - 𝛼*t)
    return max(learner_kanji , 0)
#ส่วน plot
list_t = []
list_LK = []
list_K = []
for t in range(1,10+1):
    list_t.append(t)
    
    LKt = LK(t)
    list_LK.append(LKt)
    
    Kt = K(t)
    list_K.append(Kt)
plt.plot(list_t, list_LK, label = 'LK(t)')
plt.plot(list_t, list_K, label = 'K(t)')
plt.xlabel('Days')
plt.ylabel('Kanji Lefts')
plt.legend()
plt.grid()
plt.show()
print(f'ตอนนี้ผู้ศึกษาคันจิ เหลือคันจิที่ต้องศึกษาอยู่ทั้งหมด {list_K[-1]} ตัว')
print(f'ดังนั้นตอนนี้ผู้ศึกษาคันจิ เรียนรู้คันจิได้ทั้งหมด {list_LK[-1]} ตัว')
print(list_LK)
# Out:
# ตอนนี้ผู้ศึกษาคันจิ เหลือคันจิที่ต้องศึกษาอยู่ทั้งหมด 150 ตัว
# ดังนั้นตอนนี้ผู้ศึกษาคันจิ เรียนรู้คันจิได้ทั้งหมด 1986 ตัว
# [2031, 2026, 2021, 2016, 2011, 2006, 2001, 1996, 1991, 1986]

# %% [markdown]
# จากสมการดังกล่าง เราจะหาจำนวนคันจิที่ควรเรียนต่อวันได้จากตัว $\alpha$ โดยแก้สมการได้ดังนี้ <br>
# จากสมการ $ K(t) = \left\lfloor K_0 + \alpha t - \beta t \right\rfloor $ จะได้
# $$
# \begin{aligned}
# 2136 & = \left\lfloor 214 + 160\alpha  -160 \frac{\alpha}{2} \right\rfloor \\
# 2136 & = \left\lfloor 214 + 160\alpha -80\alpha \right\rfloor \\
# 2136 & = \left\lfloor 214 + 80\alpha \right\rfloor \\
# 2136 & \leq 214 +  80\alpha < 2137 \\
# \frac{2136 - 214}{80} & \leq \alpha < \frac{2137 - 214}{80} \\
# \frac{1922}{80} & \leq \alpha < \frac{1923}{80} \\
# 24.025 & \leq \alpha < 24.0375
# \end{aligned}
# $$

# %% [markdown]
# # <span style="color:blue">The Mathematical Model Part : Quadratic Equation </span>
# คราวนี้เรามาทำตัวสมการที่จะเอาไปนำเสนอกัน โดยจะมีหน้าตาสมการดังนี้ <br>
# กำหนดให้ $ K_0 , t \in \mathbb{N}_+ $ และ $ \alpha , \beta \in \mathbb{R}_+ $
# $$ K(t) = 2136 - \left\lfloor K_0 + \alpha t - \beta \alpha t^2 \right\rfloor $$
# $$ L(t) = \left\lfloor K_0 + \alpha t - \beta \alpha t^2 \right\rfloor $$
# $\textbf{โดยตัวแปรแต่ละตัว แทนความหมายดังนี้}$ <br>
# K(t) แทน โจโยคันจิที่เหลือที่ต้องเรียน (ตัว) <br>
# L(t) แทน คันจิที่ผู้ศึกษารู้ ณ วันที่ t (ตัว) <br>
# K_0 แทน รากศัพท์ที่จำเป็นต่อการเข้าใจตัวคันจิ 214 ตัวอักษร (ตัว) <br>
# $ \alpha $ แทน ความสามารถในการเรียนรู้คันจิ (ตัว/วัน) <br>
# t แทน วันที่เรียนคันจิ (วัน) <br>
# $ \beta $ แทน อัตราการสูญเสียคันจิตามหลักการ Forgetting Curve [ตามสถิติ คือ 66.3% ต่อวัน] (ไม่มีหน่วย) <br>
# $ \gamma $ แทน อัตราเร่งการสูญเสียคันจิแบบสะสม (ตัว)

# %% [markdown]
# เมื่อ $ \alpha $ สามารถหาได้จาก <br>
# $$
# \begin{aligned}
# 2136 & = \left\lfloor 214 + 360\alpha  - 360(0.663^2)\alpha  \right\rfloor \\
# 2136 & \leq 214 + 360\alpha  - 360(0.663^2)\alpha < 2137 \\
# 1922 & \leq 360\alpha  - 360(0.663^2)\alpha < 1923 \\
# \frac{1922}{360} & \leq \alpha - 0.663^2\alpha < \frac{1923}{360} \\
# \frac{1922}{360} & \leq \alpha - 0.439569\alpha < \frac{1923}{360}
# \end{aligned}
# $$

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import matplotlib.pyplot as plt
import math 
import ipywidgets as widgets
from IPython.display import display, clear_output
#Normal Setting
l = 786
#Display Section
alpha = widgets.FloatText(description='𝛼')
beta = widgets.FloatText(description='𝛽')
time = widgets.IntText(description='t')
kanji_01 = widgets.IntText(description='k_01')
kanji_02 = widgets.IntText(description='k_02')
kanji_03 = widgets.IntText(description='k_03')
kanji_04 = widgets.IntText(description='k_04')
kanji_05 = widgets.IntText(description='k_05')
kanji_06 = widgets.IntText(description='k_06')

#Function Section
def L_1(t,𝛼,𝛽,K_01):
    I_1 = 80 + l
    if t <= 120:
        learning_j1 = math.floor((1 - 𝛽)*(K_01 + 𝛼*t))
        return min(I_1, learning_j1)
    elif t > 120 :
        learning_j1 = math.floor((1 - 𝛽)*(K_01 + 𝛼*120))
        return min(I_1, learning_j1)

def L_2(t,𝛼,𝛽,K_02):
    I_2 = 120 + (l - L_1(time.value,alpha.value,beta.value,kanji_01.value) + 80)
    if t <= 120:
        return 0
    elif (t > 120) and (t <= 240):
        learning_j2 = math.floor((1 - 𝛽)*(K_02 + 𝛼*(t-120)))
        return min(I_2, learning_j2)
    elif t > 240 :
        learning_j2 = math.floor((1 - 𝛽)*(K_02 + 𝛼*120))
        return min(I_2, learning_j2)

def L_3(t,𝛼,𝛽,K_03):
    I_3 = 250 + (l - L_1(time.value,alpha.value,beta.value,kanji_01.value) + 80 
             - L_2(time.value,alpha.value,beta.value,kanji_02.value) + 120)
    if t <= 240:
        return 0
    elif (t > 240) and (t <= 360):
        learning_j3 = math.floor((1 - 𝛽)*(K_03 + 𝛼*(t-240)))
        return min(I_3, learning_j3)
    elif t > 360 :
        learning_j3 = math.floor((1 - 𝛽)*(K_03 + 𝛼*120))
        return min(I_3, learning_j3)

def L_4(t,𝛼,𝛽,K_04):
    I_4 = 250 + (l - L_1(time.value,alpha.value,beta.value,kanji_01.value) + 80 
             - L_2(time.value,alpha.value,beta.value,kanji_02.value) + 120 
             - L_3(time.value,alpha.value,beta.value,kanji_03.value) + 250)
    if t <= 360:
        return 0
    elif (t > 360) and (t <= 480):
        learning_j4 = math.floor((1 - 𝛽)*(K_04 + 𝛼*(t-360)))
        return min(I_4, learning_j4)
    elif t > 480 :
        learning_j4 = math.floor((1 - 𝛽)*(K_04 + 𝛼*120))
        return min(I_4, learning_j4)

def L_5(t,𝛼,𝛽,K_05):
    I_5 = 300 + (l - L_1(time.value,alpha.value,beta.value,kanji_01.value) + 80 
             - L_2(time.value,alpha.value,beta.value,kanji_02.value) + 120 
             - L_3(time.value,alpha.value,beta.value,kanji_03.value) + 250 
             - L_4(time.value,alpha.value,beta.value,kanji_04.value) + 250)
    if t <= 480:
        return 0
    elif (t > 480) and (t <= 600):
        learning_j5 = math.floor((1 - 𝛽)*(K_05 + 𝛼*(t-480)))
        return min(I_5, learning_j5)
    elif t > 600 :
        learning_j5 = math.floor((1 - 𝛽)*(K_05 + 𝛼*120))
        return min(I_5, learning_j5)

def L_6(t,𝛼,𝛽,K_06):
    I_6 = 350 + (l - L_1(time.value,alpha.value,beta.value,kanji_01.value) + 80 
             - L_2(time.value,alpha.value,beta.value,kanji_02.value) + 120 
             - L_3(time.value,alpha.value,beta.value,kanji_03.value) + 250 
             - L_4(time.value,alpha.value,beta.value,kanji_04.value) + 250 
             - L_5(time.value,alpha.value,beta.value,kanji_05.value) + 300)
    if t <= 600:
        return 0
    elif (t > 600) and (t <= 720):
        learning_j6 = math.floor((1 - 𝛽)*(K_06 + 𝛼*(t-600)))
        return min(I_6, learning_j6)
    elif t > 720 :
        learning_j6 = math.floor((1 - 𝛽)*(K_06 + 𝛼*120))
        return min(I_6, learning_j6)
#Solution Check
def fine_alpha(𝛽,K_01,K_02,K_03,K_04,K_05,K_06):
    𝛼_star = (2136 - (K_01 + K_02 + K_03 + K_04 + K_05 + K_06)*(1 - 𝛽))/(720*(1 - 𝛽))
    return 𝛼_star
def out_range_fine_alpha(𝛽,K_01,K_02,K_03,K_04,K_05,K_06):
    𝛼_star = (2137 - (K_01 + K_02 + K_03 + K_04 + K_05 + K_06)*(1 - 𝛽))/(720*(1 - 𝛽))
    return 𝛼_star
#Button click event handler
def calculate(btn):
    with output:
        clear_output() 
        display(f'Japanise 1 Kanji Learned : {L_1(time.value,alpha.value,beta.value,kanji_01.value)} Character')
        display(f'Japanise 2 Kanji Learned : {L_2(time.value,alpha.value,beta.value,kanji_02.value)} Character')
        display(f'Japanise 3 Kanji Learned : {L_3(time.value,alpha.value,beta.value,kanji_03.value)} Character')
        display(f'Japanise 4 Kanji Learned : {L_4(time.value,alpha.value,beta.value,kanji_04.value)} Character')
        display(f'Japanise 5 Kanji Learned : {L_5(time.value,alpha.value,beta.value,kanji_05.value)} Character')
        display(f'Japanise 6 Kanji Learned : {L_6(time.value,alpha.value,beta.value,kanji_06.value)} Character')
        display(plot(time.value, alpha.value, beta.value, 
                     kanji_01.value, kanji_02.value, kanji_03.value, kanji_04.value, kanji_05.value, kanji_06.value))
        display(f'The fine alpha is : {fine_alpha(beta.value,kanji_01.value,kanji_02.value,kanji_03.value,kanji_04.value,kanji_05.value,kanji_06.value)} ≤ 𝛼 < {out_range_fine_alpha(beta.value,kanji_01.value,kanji_02.value,kanji_03.value,kanji_04.value,kanji_05.value,kanji_06.value)}')
#Plot Section
def plot(t,𝛼,𝛽,K_01,K_02,K_03,K_04,K_05,K_06) :
    list_Lt = []
    list_t = []
    for i in range(0,t+1):
        list_t.append(i)
    
        Lt = L_1(i,𝛼,𝛽,K_01) + L_2(i,𝛼,𝛽,K_02) + L_3(i,𝛼,𝛽,K_03) + L_4(i,𝛼,𝛽,K_04) + L_5(i,𝛼,𝛽,K_05) + L_6(i,𝛼,𝛽,K_06)
        list_Lt.append(Lt)
    plt.plot(list_t, list_Lt, label = 'L(t)')
    plt.xlabel('Days')
    plt.ylabel('Kanji learned')
    plt.legend()
    plt.grid()
    plt.show()
    return f'All Kanji Learned is {list_Lt[-1]} Character'

#User Interface Section
output = widgets.Output()
calc_button = widgets.Button(description='Calculate')
calc_button.on_click(calculate)

ui1 = widgets.VBox([alpha, beta, time, kanji_01, kanji_02, kanji_03, kanji_04, kanji_05, kanji_06])
outer = widgets.VBox([calc_button,output])
full_screen = widgets.HBox([ui1,outer])
display(full_screen)
